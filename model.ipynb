# %%
import pandas as pd
from pandas import DataFrame as df
import matplotlib as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn import linear_model, metrics
import seaborn as sb
from sklearn.metrics import accuracy_score

# %%
train_data = pd.read_csv('train.csv', low_memory=False)
test_data = pd.read_csv('test.csv', low_memory=False)

# %%
train_data.head()
# Out:
#           subscription_id observation_dt  is_retained       specialization_id  \
# 0  --rKikbGEeyQHQqIvaM5IQ     2022-05-04          1.0  kr43OcbTEeqeNBKhfgCLyw
# 1  -0XGzEq2EeyimBISGRuNeQ     2021-11-30          0.0  Q0Fc_Yl0EeqdTApgQ4tM7Q
# 2  -1P9kOb6EeuRugq1Liq62w     2021-08-13          0.0  9kmimrDIEeqxzQqieMm42w
# 3  -2ifTJZbEeuIuRKpAhovaw     2021-08-03          1.0  7lHCSlFIEeeffRIHljDI_g
# 4  -5YKZbchEeufeAq6C_fAOw     2021-06-04          0.0  kr43OcbTEeqeNBKhfgCLyw
#
#    cnt_courses_in_specialization   specialization_domain  \
# 0                            8.0            Data Science
# 1                            6.0            Data Science
# 2                            6.0                Business
# 3                            5.0  Information Technology
# 4                            8.0            Data Science
#
#   is_professional_certificate is_gateway_certificate  \
# 0                        True                   True
# ...

# %%
#using ordinal encoder
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

# %%
train_data[['specialization_domain','is_professional_certificate','is_gateway_certificate','learner_country_group','is_active_capstone_during_pay_period','learner_gender']] = encoder.fit_transform(train_data[['specialization_domain','is_professional_certificate','is_gateway_certificate','learner_country_group','is_active_capstone_during_pay_period','learner_gender']])

# %%
train_data = train_data.dropna()

# %%
train_data = train_data.drop(['subscription_id','observation_dt','specialization_id','cnt_enrollments_started_before_payment_period','cnt_enrollments_completed_before_payment_period','cnt_enrollments_active_before_payment_period','cnt_items_completed_before_payment_period','cnt_graded_items_completed_before_payment_period','is_subscription_started_with_free_trial','cnt_enrollments_started_during_payment_period','cnt_enrollments_completed_during_payment_period','cnt_enrollments_active_during_payment_period','cnt_items_completed_during_payment_period','cnt_graded_items_completed_during_payment_period','is_active_capstone_during_pay_period','sum_hours_learning_during_payment_period','sum_hours_learning_before_payment_period','cnt_days_active_during_payment_period'],axis=1)

# %%
train_data.head()
# Out:
#    is_retained  cnt_courses_in_specialization  specialization_domain  \
# 0          1.0                            8.0                    3.0
# 1          0.0                            6.0                    3.0
# 2          0.0                            6.0                    1.0
# 3          1.0                            5.0                    5.0
# 4          0.0                            8.0                    3.0
#
#    is_professional_certificate  is_gateway_certificate  \
# 0                          1.0                     1.0
# 1                          1.0                     0.0
# 2                          1.0                     1.0
# 3                          1.0                     1.0
# 4                          1.0                     1.0
#
#    learner_days_since_registration  learner_country_group  learner_gender  \
# 0                           2321.0                   10.0             0.0
# ...

# %%
1. change the learner days register to long term user, middle term user and short term user.
2. change country group to high income, mid income, low income based on per capita income
3. cnt days till last activity can be used for active and inactive user

scaling the following
cnt_courses_in_specialization



remove the following
-days till next payment due
-

very stron correlation (0.2+)
-days since last payment
-subscription period order
'cnt_days_since_last_activity'



medium correlation (0.05+)
- learner_cnt_other_courses_paid_active'
- learner_cnt_other_courses_items_completed',
- learner_cnt_other_courses_paid_items_completed',

good correlation (0.021+)
-learner other revenue
-learner_cnt_other transactions past
'cnt_days_active_before_payment_period',

Negative correlation
'cnt_enrollments_started_before_payment_period','cnt_enrollments_completed_before_payment_period','cnt_enrollments_active_before_payment_period','cnt_items_completed_before_payment_period','cnt_graded_items_completed_before_payment_period','is_subscription_started_with_free_trial','cnt_enrollments_started_during_payment_period','cnt_enrollments_completed_during_payment_period','cnt_enrollments_active_during_payment_period','cnt_items_completed_during_payment_period','cnt_graded_items_completed_during_payment_period','is_active_capstone_during_pay_period','sum_hours_learning_during_payment_period','sum_hours_learning_before_payment_period','cnt_days_active_during_payment_period',

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
train_data.head()
# Out:
#    is_retained  cnt_courses_in_specialization  specialization_domain  \
# 0          1.0                            8.0                    3.0
# 1          0.0                            6.0                    3.0
# 2          0.0                            6.0                    1.0
# 3          1.0                            5.0                    5.0
# 4          0.0                            8.0                    3.0
#
#    is_professional_certificate  is_gateway_certificate  \
# 0                          1.0                     1.0
# 1                          1.0                     0.0
# 2                          1.0                     1.0
# 3                          1.0                     1.0
# 4                          1.0                     1.0
#
#    learner_days_since_registration  learner_country_group  learner_gender  \
# 0                           2321.0                   10.0             0.0
# ...

# %%
train_data["learner_days_since_registration"] = scaler.fit_transform(train_data["learner_days_since_registration"].values.reshape(-1,1))
train_data["learner_cnt_other_courses_active"] = scaler.fit_transform(train_data["learner_cnt_other_courses_active"].values.reshape(-1,1))

train_data["learner_cnt_other_courses_items_completed"] = scaler.fit_transform(train_data["learner_cnt_other_courses_items_completed"].values.reshape(-1,1))
train_data["learner_cnt_other_courses_paid_items_completed"] = scaler.fit_transform(train_data["learner_cnt_other_courses_paid_items_completed"].values.reshape(-1,1))
train_data["learner_other_revenue"] = scaler.fit_transform(train_data["learner_other_revenue"].values.reshape(-1,1))

train_data["subscription_period_order"] = scaler.fit_transform(train_data["subscription_period_order"].values.reshape(-1,1))
train_data["days_since_last_payment"] = scaler.fit_transform(train_data["days_since_last_payment"].values.reshape(-1,1))

train_data["days_til_next_payment_due"] = scaler.fit_transform(train_data["days_til_next_payment_due"].values.reshape(-1,1))
train_data["cnt_days_active_before_payment_period"] = scaler.fit_transform(train_data["cnt_days_active_before_payment_period"].values.reshape(-1,1))

train_data["cnt_days_since_last_activity"] = scaler.fit_transform(train_data["cnt_days_since_last_activity"].values.reshape(-1,1))

# %%
y_train = train_data['is_retained']
train_data = train_data.drop(['is_retained'],axis=1)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(train_data,y_train,test_size=0.3,shuffle=True)

# %%
#train_data = scaler.fit_transform(train_data.values.reshape(-1,1))

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
hgb = HistGradientBoostingClassifier(max_iter=1000)

# %%
hgb.fit(xtrain,ytrain)
hgb_test_predict = hgb.predict(xtest)
hgb_test_predict
# Out:
# array([1., 1., 1., ..., 1., 0., 1.])

# %%
accuracy_score(ytest, hgb_test_predict)
# Out:
# 0.6725878923550158

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=200)
classifier.fit(xtrain, ytrain)
# Out:
# LogisticRegression(max_iter=200)

# %%
lr_test_predict = classifier.predict(xtest)

# %%
accuracy_score(ytest, lr_test_predict)
# Out:
# 0.6500974344934212

# %%
logreg0 = LogisticRegression()
grid= {"C": np.logspace(-3,3,7), "penalty":["l1","l2"]}
logreg_cv = GridSearchCV(logreg0,grid,cv=10)
logreg_cv.fit(xtrain, ytrain)
print("Best parameters of Logistic Regression :",logreg_cv.best_params_)
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\moham\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
logreg = LogisticRegression(C=logreg_cv.best_params_["C"] , penalty=logreg_cv.best_params_["penalty"])
logreg = logreg.fit(xtrain, ytrain) 
#print("Logistic Regression Accuracy :",logreg.score(test_x,test_y))
logreg_prediction = logreg.predict(xtest)
accuracy_score(ytest, logreg_prediction)
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6502262734929863

# %%
pip install xgboost
# Out:
# ...
#      ---------------------------------------- 89.1/89.1 MB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# %%
xg_reg = xgb.XGBClassifier(objective ="reg:logistic", colsample_bytree = 0.99, learning_rate = 0.01,
                max_depth = 9, alpha = 10, n_estimators = 20, gamma=1, reg_lambda=0.1, subsample=0.8,)

# %%
xg_model = xg_reg.fit(xtrain, ytrain)

# %%
xg_model_prediction = xg_model.predict(xtest)

# %%
accuracy_score(ytest, xg_model_prediction)
# Out:
# 0.664801185318796

# %%
from sklearn.model_selection import GridSearchCV

# %%
xgb_cl = xgb.XGBClassifier(objective="binary:logistic")

# %%
param_grid = {
    "max_depth": [3, 4, 5, 7],
    "learning_rate": [0.1, 0.01, 0.05],
    "gamma": [0, 0.25, 1],
    "reg_lambda": [0, 1, 10],
    "scale_pos_weight": [1, 3, 5],
    "subsample": [0.8],
    "colsample_bytree": [0.5],
}

# %%
grid_cv = GridSearchCV(xgb_cl, param_grid, n_jobs=-1, cv=3, scoring="roc_auc")

# %%
boost_model = grid_cv.fit(xtrain, ytrain)

# %%
boost_model.best_score_
# Out:
# 0.7316642605156747
